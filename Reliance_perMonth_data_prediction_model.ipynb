# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
#df=C:\Users\BESTSELLER\Desktop\coding\RELIANCE_Stock_data.xls

# %%
df= pd.read_excel(r'C:\Users\BESTSELLER\Desktop\coding\RELIANCE_Stock_data.xls')

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2012-07-01   364.296844   369.547058   350.007294   368.308807
# 1   2012-08-01   366.649536   408.577087   361.845062   379.601746
# 2   2012-09-01   380.394257   436.660889   376.456573   414.669342
# 3   2012-10-01   416.056213   426.952911   337.971375   398.968170
# 4   2012-11-01   393.767487   403.624054   376.976624   393.123596
# ..         ...          ...          ...          ...          ...
# 116 2022-03-01  2359.550049  2688.000000  2180.000000  2634.750000
# 117 2022-04-01  2636.000000  2856.149902  2521.800049  2790.250000
# 118 2022-05-01  2762.000000  2805.500000  2370.000000  2632.649902
# 119 2022-06-01  2634.300049  2817.350098  2554.000000  2590.000000
# 120 2022-06-17  2560.000000  2624.850098  2556.100098  2590.000000
#
#        Adj Close     Volume
# 0     344.117737  100129560
# 1     354.668945  143638045
# 2     387.433197  152276198
# 3     372.763336  133048777
# ...

# %%
feature_cols=['Open','High','Low']
x=df[feature_cols]
y=df['Close']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(x, y, test_size=0.5)

# %%
X_train
# Out:
#             Open         High          Low
# 34    427.126282   453.402191   424.575439
# 76   1057.872437  1174.863525  1040.140503
# 26    497.459595   515.761108   454.343292
# 16    450.777069   458.924866   413.703491
# 25    492.828491   506.697021   480.941162
# 87   1324.445557  1475.662231  1269.268555
# 30    438.988831   462.862518   411.697510
# 31    453.724152   467.468872   414.372162
# 82   1379.721558  1404.189697  1215.973755
# 28    497.286224   503.898560   477.176849
# 112  2536.250000  2602.199951  2309.000000
# 68    940.831848   950.886536   871.736816
# 62    792.413696   864.307251   771.784241
# 85   1152.475708  1292.201172  1085.015137
# 98   2100.000000  2369.350098  2044.250000
# 24    503.824249   516.751709   474.749847
# 14    422.594238   446.269806   405.704315
# 71    911.361206  1026.271973   909.825745
# 38    422.940948   445.526855   408.676147
# 52    520.714172   523.017334   460.633667
# 75   1245.890259  1245.890259  1006.856018
# ...

# %%
from sklearn.linear_model import LinearRegression
linreg= LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 6.5591640277002625
# [-0.50423109  0.8387673   0.63821928]

# %%
y_pred=linreg.predict(X_test)

# %%
y_pred
# Out:
# array([1020.79090795,  410.70544873,  703.82661252, 1178.82901693,
#        1234.15622005, 1115.00753473, 1253.35759755,  449.87885274,
#         421.2712701 , 2548.7183601 ,  441.98722201, 1903.63971682,
#        1312.39036791,  449.16110964, 2072.48907391, 2150.64058745,
#         529.68120608, 1062.91386702,  882.33531621, 1921.63845201,
#        2053.44831762, 2462.72519802,  415.50497736,  387.14976129,
#        2074.22875334,  532.81108943,  640.45399828,  469.52514808,
#         412.97085795, 1395.30089783,  884.21332996,  456.87195178,
#         477.99575077,  500.95852091,  460.38490728,  464.6829484 ,
#        1348.9434142 , 2090.76100452,  511.94314781,  590.49737633,
#         510.98154934,  436.34139813, 2284.24445123, 2479.61423987,
#         356.2147595 ,  906.03573241,  476.03255017,  515.84308469,
#        2070.01303406, 1495.42211215, 2309.56762111,  435.6717672 ,
#         396.24710154, 2438.51540072,  942.09558819,  468.01351129,
# ...

# %%
from sklearn import metrics
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
data= X_test[['Open','High','Low']]
data['actual_closing']=y_test
data['predicted_closing_price']=y_pred
data
# Out:
# 49.70943254677168
#            Open         High          Low  actual_closing  \
# 92  1342.375610  1356.145142   867.427673     1103.291870
# 5    393.767487   420.910187   391.167114      415.833313
# 57   664.699341   726.983948   662.247559      691.049561
# 78  1114.683960  1252.824463  1070.948486     1215.627075
# 86  1236.826172  1323.207275  1161.638794     1319.740234
# ..          ...          ...          ...             ...
# 3    416.056213   426.952911   337.971375      398.968170
# 11   398.076630   432.401276   384.009979      427.250092
# 83  1322.464355  1361.345825  1236.925171     1241.333374
# 79  1222.412720  1308.793945  1194.675659     1219.490479
# 47   474.477417   492.407471   462.317688      480.024841
#
#     predicted_closing_price
# 92              1020.790908
# 5                410.705449
# 57               703.826613
# 78              1178.829017
# 86              1234.156220
# ..                      ...
# 3                370.584673
# ...

# %%
import plotly_express as px
figg=px.scatter(data, x='Open', y='predicted_closing_price', hover_data=['actual_closing'])
figg.show()
# Out:
# <div>                            <div id="cc9826c1-a6f4-4b49-913a-5027ae747505" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc9826c1-a6f4-4b49-913a-5027ae747505")) {                    Plotly.newPlot(                        "cc9826c1-a6f4-4b49-913a-5027ae747505",                        [{"customdata":[[1103.29187],[415.833313],[691.049561],[1215.627075],[1319.740234],[1174.863525],[1229.990967],[427.126282],[414.669342],[2590.0],[431.930725],[1994.5],[1350.449097],[461.005127],[2054.5],[2110.649902],[536.762024],[1110.721436],[912.896667],[1985.300049],[2085.800049],[2634.75],[411.67276],[393.123596],[2003.099976],[522.522034],[654.248352],[479.00946],[403.103973],[1316.17395],[945.586792],[439.16217],[502.536469],[486.736237],[478.786591],[469.
# ...

# %%
px.scatter?
